# %%
import pandas as pd
import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv')

# %%
train.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 850    851         120       RM         36.0     4435   Pave   NaN      Reg
# 202    203          50       RL         50.0     7000   Pave   NaN      Reg
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1060  1061         120       RL         41.0     4920   Pave   NaN      Reg
# 624    625          60       RL         80.0    10400   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 850          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 202          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1435         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 1060         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 624          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 850      11   2007        WD         Normal     131500
# 202       5   2006       COD         Normal     112000
# 1435      7   2008       COD        Abnorml     174000
# 1060      4   2010        WD         Normal     213500
# 624      11   2006        WD         Normal     165150
#
# [5 rows x 81 columns]

# %%
profile = train.profile_report(title='Pandas Profiling Report')
profile.to_file(output_file="house_price_prediction.html")
